# %% [markdown]
# <a href="https://colab.research.google.com/github/Datadog-995/data--quality--portfolio/blob/main/Data_Quality_Pipeline_Butcher_Sales.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# Fetch the live, updated dataset directly from your GitHub repository
url = "https://raw.githubusercontent.com/Datadog-995/data--quality--portfolio/main/data/cleaned/CLEANED-butcher-sales-dirty-4000-CLEANED%20VERSION%20-EN-csv.csv"
df = pd.read_csv(url)

# Create a boolean mask to locate rows where the Date column is blank or null
missing_date_mask = df['Date'].isna() | (df['Date'].astype(str).str.strip() == '')

# Isolate and display only the rows matching our anomaly criteria
flagged_rows = df[missing_date_mask]
print(f"Total anomalies flagged for human review: {len(flagged_rows)}")
flagged_rows[['Store', 'Product', 'Total Sales', 'Audit Notes']]
# Out:
# Total anomalies flagged for human review: 168
#                 Store      Product Total Sales  \
# 38       Fine Cuts Mx         Beef     $285.48
# 43       Fine Cuts Mx      Chicken     $176.92
# 57    The Little Bull  Skirt Steak     $227.33
# 69        Super Meats  Skirt Steak     $454.23
# 93      North Butcher         Beef    $1895.80
# ...               ...          ...         ...
# 3671      Super Meats  Skirt Steak    $1010.14
# 3675      Super Meats         Pork     $275.16
# 3676  The Little Bull         Ribs    $1959.66
# 3677  The Little Bull  Skirt Steak     $214.98
# 3687    North Butcher      Chicken     $179.59
#
#                               Audit Notes
# 38    🚨 Missing Date - Flagged for Review
# 43    🚨 Missing Date - Flagged for Review
# 57    🚨 Missing Date - Flagged for Review
# 69    🚨 Missing Date - Flagged for Review
# 93                                    NaN
# ...                                   ...
# 3671                                  NaN
# ...

# %%
import pandas as pd

# Fetch the live, updated dataset directly from your GitHub repository
url = "https://raw.githubusercontent.com/Datadog-995/data--quality--portfolio/main/data/cleaned/CLEANED-butcher-sales-dirty-4000-CLEANED%20VERSION%20-EN-csv.csv"
df = pd.read_csv(url)

print(f"Dataset loaded successfully. Total rows: {len(df)}")
df.head(10)
# Out:
# Dataset loaded successfully. Total rows: 3688
#          Date            Store      Product    Price  Quantity Total Sales  \
# 0  2025-11-25    North Butcher         Beef  $174.84      11.0    $1923.24
# 1  2025-05-27     Fine Cuts Mx      Unknown  $143.09      19.0    $2718.71
# 2  2025-12-23        Happy Cow      Chicken  $634.44       3.0    $1903.32
# 3  2025-11-01  The Little Bull         Beef  $151.11      10.0    $1511.10
# 4  2026-01-05    North Butcher         Beef  $128.61      15.0    $1929.15
# 5  2025-09-18        Happy Cow      Chicken  $153.38       3.0     $460.14
# 6  2025-05-27      Super Meats  Skirt Steak   $78.76       9.0     $708.84
# 7  2025-06-16    North Butcher  Skirt Steak  $119.97      15.0    $1799.55
# 8  2026-03-06        Happy Cow         Ribs  $135.42       8.0    $1083.36
# 9  2025-12-24      Super Meats      Sausage  $191.13       2.0     $382.26
#
#   Audit Notes
# 0         NaN
# 1         NaN
# 2         NaN
# 3         NaN
# 4         NaN
# ...

# %%
### Step 2: Automated Anomaly Isolation
Instead of blindly dropping records that have critical missing tracking variables (like an empty transaction date), the automation engine flags them with an explicit audit note so accounting teams can easily filter and review them later.
# Out:
#   File "/tmp/ipykernel_34845/16992678.py", line 2
#     Instead of blindly dropping records that have critical missing tracking variables (like an empty transaction date), the automation engine flags them with an explicit audit note so accounting teams can easily filter and review them later.
#             ^
# SyntaxError: invalid syntax

# %%
# Create a boolean mask to locate rows where the Date column is blank or null
missing_date_mask = df['Date'].isna() | (df['Date'].astype(str).str.strip() == '')

# Isolate and display only the rows matching our anomaly criteria
flagged_rows = df[missing_date_mask]
print(f"Total anomalies flagged for human review: {len(flagged_rows)}")
flagged_rows[['Store', 'Product', 'Total Sales', 'Audit Notes']]
# Out:
# Total anomalies flagged for human review: 168
#                 Store      Product Total Sales  \
# 38       Fine Cuts Mx         Beef     $285.48
# 43       Fine Cuts Mx      Chicken     $176.92
# 57    The Little Bull  Skirt Steak     $227.33
# 69        Super Meats  Skirt Steak     $454.23
# 93      North Butcher         Beef    $1895.80
# ...               ...          ...         ...
# 3671      Super Meats  Skirt Steak    $1010.14
# 3675      Super Meats         Pork     $275.16
# 3676  The Little Bull         Ribs    $1959.66
# 3677  The Little Bull  Skirt Steak     $214.98
# 3687    North Butcher      Chicken     $179.59
#
#                               Audit Notes
# 38    🚨 Missing Date - Flagged for Review
# 43    🚨 Missing Date - Flagged for Review
# 57    🚨 Missing Date - Flagged for Review
# 69    🚨 Missing Date - Flagged for Review
# 93                                    NaN
# ...                                   ...
# 3671                                  NaN
# ...
